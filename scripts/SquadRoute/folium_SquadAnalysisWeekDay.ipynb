# %% [markdown]
# # Analysis 24.09. - 30.09.2016
# After declaring our helper-functions, we visualize the different days of the period to see if the squads move during the week.

# %%
import pandas as pd
import feather as fth

import folium
from folium import features
from folium.plugins import HeatMap
from folium.plugins import HeatMapWithTime

new_york_coordinates = (40.75, -74.00) #starting point for maps - middle of nyc

def load( precinct, squad, date):
    file = 'geo_squad_route_time_' + squad + precinct + '_' + date + '_Parking_Violations_' + str(int(date[-2:]) + 1)
    datadir = '../../data/nyc_parking_tickets/squad_route/'
    fileformat = '.fth'
    path = datadir + file + fileformat
    
    data = fth.read_dataframe(path)
    data = data[['lat', 'lng', 'Violation Time']]
    
    return data

def prepare( dataIn ):
    dataHourMin = []
    for x in range(1, 13):
        datatemp = dataIn[dataIn['Violation Time'].str[:2].str.contains(str(x).zfill(2))]
        for y in range(0, 59):
            datatemp2 = []
            datatemp2 = datatemp[datatemp['Violation Time'].str[2:4].str.contains(str(y).zfill(2))]
            
            if not datatemp2.empty:
                datatemp2 = datatemp2[['lat','lng']].values.tolist()
                dataHourMin.append(datatemp2)
                
    return dataHourMin

def sortTime( data ):
    
    #print('Processing...')
    
    dataAM = data[data['Violation Time'].str.contains('A')]
    #dataAM['Violation Time'] = dataAM['Violation Time'].str[:4]
    dataPM = data[data['Violation Time'].str.contains('P')]

    dataAM = dataAM.sort_values(by=['Violation Time'])
    dataPM = dataPM.sort_values(by=['Violation Time'])
    data = dataAM[['lat', 'lng']]
    data = data.append(dataPM[['lat', 'lng']])

    dataTimeSort = data.values.tolist()
    #print('Done!')
    
    return dataTimeSort

# %%
dataSquadWeek = []
#dataSquadWeekDays 

tmp = load('120', 'A', '09242016')
day1 = sortTime(tmp)
dataSquadWeek.extend(day1)

tmp = load('120', 'A', '09252016')
day2 = sortTime(tmp)
dataSquadWeek.extend(day2)

tmp = load('120', 'A', '09262016')
day3 = sortTime(tmp)
dataSquadWeek.extend(day3)

tmp = load('120', 'A', '09272016')
day4 = sortTime(tmp)
dataSquadWeek.extend(day4)

tmp = load('120', 'A', '09282016')
day5 = sortTime(tmp)
dataSquadWeek.extend(day5)

tmp = load('120', 'A', '09292016')
day6 = sortTime(tmp)
dataSquadWeek.extend(day6)

tmp = load('120', 'A', '09302016')
day7 = sortTime(tmp)
dataSquadWeek.extend(day7)

print('Done!')
# Out:
# Done!

# %% [markdown]
# # Day 1 - 24.09.2016 - Saturday

# %%
pubs_map = folium.Map(location=new_york_coordinates, zoom_start=11)
HeatMap(day1, radius = 15).add_to(pubs_map)

pubs_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
pubs_map = folium.Map(location=new_york_coordinates, zoom_start=11)

data = day1

for each in data:
    folium.Marker(location=each, popup=str(each)).add_to(pubs_map)
    continue
folium.PolyLine(data, color="green", weight=2.5, opacity=1).add_to(pubs_map)

pubs_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Day 2

# %%
pubs_map = folium.Map(location=new_york_coordinates, zoom_start=11)
HeatMap(day2, radius = 15).add_to(pubs_map)

pubs_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
pubs_map = folium.Map(location=new_york_coordinates, zoom_start=11)

data = day2

for each in data:
    folium.Marker(location=each, popup=str(each)).add_to(pubs_map)
    continue
folium.PolyLine(data, color="green", weight=2.5, opacity=1).add_to(pubs_map)

pubs_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Day 3

# %%
pubs_map = folium.Map(location=new_york_coordinates, zoom_start=11)
HeatMap(day3, radius = 15).add_to(pubs_map)

pubs_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
pubs_map = folium.Map(location=new_york_coordinates, zoom_start=11)

data = day3

for each in data:
    folium.Marker(location=each, popup=str(each)).add_to(pubs_map)
    continue
folium.PolyLine(data, color="green", weight=2.5, opacity=1).add_to(pubs_map)

pubs_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Day 4

# %%
pubs_map = folium.Map(location=new_york_coordinates, zoom_start=11)
HeatMap(day4, radius = 15).add_to(pubs_map)

pubs_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
pubs_map = folium.Map(location=new_york_coordinates, zoom_start=11)

data = day4

for each in data:
    folium.Marker(location=each, popup=str(each)).add_to(pubs_map)
    continue
folium.PolyLine(data, color="green", weight=2.5, opacity=1).add_to(pubs_map)

pubs_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Day 5

# %%
pubs_map = folium.Map(location=new_york_coordinates, zoom_start=11)
HeatMap(day5, radius = 15).add_to(pubs_map)

pubs_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
pubs_map = folium.Map(location=new_york_coordinates, zoom_start=11)

data = day5

for each in data:
    folium.Marker(location=each, popup=str(each)).add_to(pubs_map)
    continue
folium.PolyLine(data, color="green", weight=2.5, opacity=1).add_to(pubs_map)

pubs_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Day 6

# %%
pubs_map = folium.Map(location=new_york_coordinates, zoom_start=11)
HeatMap(day6, radius = 15).add_to(pubs_map)

pubs_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
pubs_map = folium.Map(location=new_york_coordinates, zoom_start=11)

data = day6

for each in data:
    folium.Marker(location=each, popup=str(each)).add_to(pubs_map)
    continue
folium.PolyLine(data, color="green", weight=2.5, opacity=1).add_to(pubs_map)

pubs_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Day 7

# %%
pubs_map = folium.Map(location=new_york_coordinates, zoom_start=11)
HeatMap(day7, radius = 15).add_to(pubs_map)

pubs_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
pubs_map = folium.Map(location=new_york_coordinates, zoom_start=11)

data = day7

for each in data:
    folium.Marker(location=each, popup=str(each)).add_to(pubs_map)
    continue
folium.PolyLine(data, color="green", weight=2.5, opacity=1).add_to(pubs_map)

pubs_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Week
# When visualizing the data of the whole week, we see, that records spread across the precinct-boundaries. The Squads are probably moving to different areas throughout the week. Also the false records migth still be an issue.

# %%
pubs_map = folium.Map(location=new_york_coordinates, zoom_start=11)
HeatMap(dataSquadWeek, radius = 15).add_to(pubs_map)

pubs_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
