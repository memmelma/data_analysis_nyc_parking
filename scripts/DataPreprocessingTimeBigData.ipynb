# %% [markdown]
# DataPreprocessing extract data from a specific date out of a dataset

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

apikey = "AIzaSyApj3xGPGx1naRs2DZiUlJ6moRftzWzTJU"

datadir = '../data/nyc_parking_tickets/'
file = 'Parking_Violations_Issued_-_Fiscal_Year_2016.csv'
path = datadir + file

# %%
#Load whole dataset
reader = pd.read_csv(path, chunksize = 1000, sep=',')
#, error_bad_lines=False
data = pd.DataFrame()
for chunk in reader:
    data = pd.concat([data, chunk])
    
data.head()
print('Loaded Dataset')
# Out:
#      Summons Number  Plate ID Registration State Plate Type  Issue Date  \
# 0        5092469481   GZH7067                 NY        PAS  07/10/2016
# 1        5092451658   GZH7067                 NY        PAS  07/08/2016
# 2        4006265037   FZX9232                 NY        PAS  08/23/2016
# 3        8478629828   66623ME                 NY        COM  06/14/2017
# 4        7868300310   37033JV                 NY        COM  11/21/2016
# 5        5096917368   FZD8593                 NY        PAS  06/13/2017
# 6        1413609545    X20DCM                 NJ        PAS  08/03/2016
# 7        4628525523    326SF9                 MA        PAS  12/21/2016
# 8        4627113330   HCA5464                 NY        OMS  11/21/2016
# 9        4006478550   VAD7274                 VA        PAS  10/05/2016
# 10       1407740258   2513JMG                 NY        COM  01/11/2017
# 11       8009901763   13657MD                 NY        COM  09/27/2016
# 12       4625926610  N102911C                 NY        OMT  10/27/2016
# 13       1416492320   FGR5997                 NY        PAS  09/30/2016
# 14       1413656420  T672371C                 NY        PAS  02/04/2017
# 15       7959486440   GYF2052                 NY        PAS  07/07/2016
# 16       5093620865   AD80228                 AZ        PAS  09/24/2016
# 17       8480309064   51771JW                 NY        COM  01/26/2017
# 18       1416638830    GLP367                 NY        PAS  04/30/2017
# 19       4630524241    HJBP29                 FL        PAS  02/03/2017
# 20       8505131836   87155MA                 NY        COM  05/27/2017
# 21       8472853342   HJN6543                 NY        PAS  10/04/2016
# 22       8513520615   77026MG                 NY        COM  05/31/2017
# 23       8556155431   HFB9919                 NY        PAS  05/26/2017
# 24       8483087236   76822MH                 NY        COM  05/19/2017
# 25       8513914599   65572JU                 NY        COM  06/09/2017
# 26       8344027755   GUP8589                 NY        PAS  12/07/2016
# 27       8040135217   GTV5924                 NY        PAS  11/19/2016
# 28       8466021980   GSC6098                 NY        PAS  12/27/2016
# 29       8357020770    Y56DLT                 NJ        PAS  01/20/2017
# ..              ...       ...                ...        ...         ...
# 970      8476904253   97036JE                 NY        COM  01/23/2017
# 971      7994359840   GNG1097                 TX        PAS  07/15/2016
# 972      7433187960   2330830                 ME        PAS  03/06/2017
# 973      7369979570   GTC5499                 NY        PAS  07/20/2016
# 974      7170603627   GDE5084                 NY        PAS  08/17/2016
# 975      8327056311    809RGE                 FL        PAS  01/11/2017
# 976      8388024498   HGF2284                 NY        PAS  11/14/2016
# 977      8516050920   GXY1094                 NY        PAS  03/03/2017
# 978      8467017971   EWV3891                 NY        PAS  10/26/2016
# 979      1413231070   28606MH                 NY        COM  08/19/2016
# 980      8117027999   83317ME                 NY        COM  09/27/2016
# 981      1410726095   DEP4792                 NC        PAS  07/15/2016
# 982      8550508081   GYK6894                 NY        PAS  05/22/2017
# 983      8470577803    W468KH                 IA        PAS  02/04/2017
# 984      8537307087   FLN2294                 NY        PAS  04/12/2017
# 985      4628411931   GTJ9563                 NY        PAS  12/16/2016
# 986      8210526881   3MD9721                 MD        PAS  10/11/2016
# 987      8378015798    DYBL66                 FL        PAS  08/09/2016
# 988      8484877693    XBYG52                 NJ        PAS  05/12/2017
# 989      4628277370   DJF3555                 NY        PAS  12/15/2016
# 990      8546468965   37489BB                 NY        OMR  06/12/2017
# 991      5093533919   CYU4598                 NY        PAS  09/16/2016
# 992      7035942324   HHU3520                 NY        PAS  09/06/2016
# 993      8509669090   91656MC                 NY        COM  04/28/2017
# 994      8473761297   33049MJ                 NY        COM  02/01/2017
# 995      8482055392   92638JU                 NY        COM  01/25/2017
# 996      4624905880   FAM2543                 NY        PAS  10/11/2016
# 997      8478353860    VUE95C                 NJ        PAS  12/06/2016
# 998      8530104183   EMK4874                 NY        PAS  03/21/2017
# 999      7036196488   HDS6837                 NY        PAS  09/29/2016
#
#      Violation Code Vehicle Body Type Vehicle Make Issuing Agency  \
# 0                 7              SUBN        TOYOT              V
# 1                 7              SUBN        TOYOT              V
# 2                 5              SUBN         FORD              V
# 3                47              REFG        MITSU              T
# 4                69              DELV        INTER              T
# 5                 7              SUBN        ME/BE              V
# 6                40               SDN        TOYOT              P
# 7                36                UT          BMW              V
# 8                36              SUBN        DODGE              V
# 9                 5                4D          BMW              V
# 10               78              DELV        FRUEH              P
# 11               19              DELV        KENWO              T
# 12               36               VAN         FORD              V
# 13               21               SDN        NISSA              P
# 14               40              TAXI        TOYOT              P
# 15               71              4DSD        VOLKS              T
# 16                7                TK         FORD              V
# 17               64               VAN        INTER              T
# 18               20              SUBN        DODGE              P
# 19               36                4D          BMW              V
# 20               38               VAN        CHEVR              T
# 21               71              2DSD        LINCO              T
# 22               14              TRAC        VOLVO              T
# 23               75              4DSD        DODGE              T
# 24               10              DELV          HIN              T
# 25               69               VAN         FORD              T
# 26               21              SUBN        NISSA              T
# 27               38              SUBN        HONDA              T
# 28               50              4DSD        NISSA              T
# 29               21              4DSD        CHEVR              T
# ..              ...               ...          ...            ...
# 970              47               VAN          GMC              T
# 971              14              SUBN        HONDA              T
# 972              14              TRLR        NS/OT              T
# 973              21              4DSD        CHEVR              T
# 974              40              4DSD        TOYOT              T
# 975              21              SUBN        TOYOT              T
# 976              20              SUBN         FORD              T
# 977              21              SUBN         AUDI              T
# 978              37              4DSD        INFIN              T
# 979              48               VAN         FORD              P
# 980              14               VAN        DODGE              T
# 981              14               NaN          BMW              S
# 982              38              SUBN        MERCU              T
# 983              38              PICK        DODGE              T
# 984              40              4DSD        ME/BE              T
# 985              36              4DSD        MITSU              V
# 986              40              SUBN        PORSC              T
# 987              46              SUBN        ROVER              T
# 988              14               VAN        ISUZU              T
# 989              36              4DSD        HONDA              V
# 990              46               BUS          NaN              T
# 991               7              SUBN        HYUND              V
# 992              38              CONV         FORD              T
# 993              40               VAN        WORKH              T
# 994              14              DELV        ISUZU              T
# 995              14               VAN        INTER              T
# 996              36              4DSD        CHRYS              V
# 997              14              4DSD        LEXUS              T
# 998              38              4DSD        LEXUS              T
# 999              40              4DSD        TOYOT              T
#
#      Street Code1           ...             Vehicle Color  \
# 0               0           ...                        GY
# 1               0           ...                        GY
# 2               0           ...                        BK
# 3           10610           ...                        WH
# 4           10510           ...                     WHITE
# 5               0           ...                        WH
# 6           54070           ...                     WHITE
# 7               0           ...                       NaN
# 8               0           ...                        BK
# 9               0           ...                       BLK
# 10              0           ...                     WHITE
# 11          10510           ...                        RD
# 12              0           ...                        WH
# 13          53620           ...                       TAN
# 14          59630           ...                       BLK
# 15          70407           ...                        GY
# 16              0           ...                       NaN
# 17          17850           ...                     BROWN
# 18          17650           ...                       BLK
# 19              0           ...                       SIL
# 20          27050           ...                        WH
# 21          39680           ...                        RD
# 22          15710           ...                     GREEN
# 23          10090           ...                        GY
# 24          10810           ...                        WH
# 25          10110           ...                        WH
# 26          67730           ...                     SILVE
# 27          13610           ...                        WH
# 28              0           ...                        WH
# 29          60810           ...                     BLACK
# ..            ...           ...                       ...
# 970         10210           ...                     BROWN
# 971         18950           ...                      GOLD
# 972         11690           ...                     GREEN
# 973         15020           ...                        WH
# 974         28115           ...                     GREEN
# 975         77430           ...                     WHITE
# 976         56630           ...                        BL
# 977         25390           ...                        WH
# 978         19340           ...                        WH
# 979         19690           ...                     BROWN
# 980         17630           ...                     WHITE
# 981         73690           ...                     BLACK
# 982          8480           ...                        GL
# 983         13610           ...                     WHITE
# 984         87250           ...                        WH
# 985             0           ...                        GY
# 986          8590           ...                     BLACK
# 987         77150           ...                     OTHER
# 988         34630           ...                     GREEN
# 989             0           ...                        RD
# 990         77030           ...                        YW
# 991             0           ...                        GY
# 992         35530           ...                        BK
# 993         33910           ...                     BROWN
# 994         18250           ...                        RD
# 995         18150           ...                     BROWN
# 996             0           ...                        BK
# 997         15510           ...                     WHITE
# 998          8320           ...                        GY
# 999         16290           ...                        RD
#
#      Unregistered Vehicle?  Vehicle Year  Meter Number  Feet From Curb  \
# 0                      NaN          2001           NaN               0
# 1                      NaN          2001           NaN               0
# 2                      NaN          2004           NaN               0
# 3                      NaN          2007           NaN               0
# 4                      NaN          2007           NaN               0
# 5                      NaN          2012           NaN               0
# 6                      0.0             0             -               1
# 7                      NaN          2001           NaN               0
# 8                      NaN          2016           NaN               0
# 9                      NaN          2008           NaN               0
# 10                     0.0          2015             -               0
# 11                     NaN          2013           NaN               0
# 12                     NaN          2008           NaN               0
# 13                     0.0             0             -               0
# 14                     0.0          2015             -               0
# 15                     NaN          2012           NaN               0
# 16                     NaN          2009           NaN               0
# 17                     NaN          2007           NaN               0
# 18                     0.0          2009             -               0
# 19                     NaN          2009           NaN               0
# 20                     NaN          2016           NaN               0
# 21                     NaN          1989           NaN               0
# 22                     NaN          2016           NaN               0
# 23                     NaN          2013           NaN               0
# 24                     NaN          2012           NaN               0
# 25                     NaN          2009           NaN               0
# 26                     NaN          2008           NaN               0
# 27                     NaN          2014           NaN               0
# 28                     NaN          2009           NaN               0
# 29                     NaN             0           NaN               0
# ..                     ...           ...           ...             ...
# 970                    NaN          1990           NaN               0
# 971                    NaN             0           NaN               0
# 972                    NaN             0           NaN               0
# 973                    NaN          2014           NaN               0
# 974                    NaN          1996           NaN               4
# 975                    NaN             0           NaN               0
# 976                    NaN          2003           NaN               0
# 977                    NaN          2013           NaN               0
# 978                    NaN          2015      429-3002               0
# 979                    0.0          2015             -               0
# 980                    NaN          2005           NaN               0
# 981                    0.0             0             -               0
# 982                    NaN          2004           NaN               0
# 983                    NaN             0           NaN               0
# 984                    NaN          2012           NaN               0
# 985                    NaN          2010           NaN               0
# 986                    NaN             0           NaN               3
# 987                    NaN             0           NaN               0
# 988                    NaN             0           NaN               0
# 989                    NaN          2003           NaN               0
# 990                    NaN          2008           NaN               0
# 991                    NaN          2011           NaN               0
# 992                    NaN          2016           NaN               0
# 993                    NaN          2012           NaN               4
# 994                    NaN          2017           NaN               0
# 995                    NaN          2006           NaN               0
# 996                    NaN          2006           NaN               0
# 997                    NaN             0           NaN               0
# 998                    NaN          2014           NaN               0
# 999                    NaN          2016           NaN               5
#
#      Violation Post Code           Violation Description  \
# 0                    NaN    FAILURE TO STOP AT RED LIGHT
# 1                    NaN    FAILURE TO STOP AT RED LIGHT
# 2                    NaN              BUS LANE VIOLATION
# 3                     04           47-Double PKG-Midtown
# 4                   31 6   69-Failure to Disp Muni Recpt
# 5                    NaN    FAILURE TO STOP AT RED LIGHT
# 6                    NaN                             NaN
# 7                    NaN  PHTO SCHOOL ZN SPEED VIOLATION
# 8                    NaN  PHTO SCHOOL ZN SPEED VIOLATION
# 9                    NaN              BUS LANE VIOLATION
# 10                   NaN                             NaN
# 11                  01 9          19-No Stand (bus stop)
# 12                   NaN  PHTO SCHOOL ZN SPEED VIOLATION
# 13                   NaN                             NaN
# 14                   NaN                             NaN
# 15                  C-PM   71-Insp. Sticker Missing (NYS
# 16                   NaN    FAILURE TO STOP AT RED LIGHT
# 17                    06   64-No STD Ex Con/DPL, D/S Dec
# 18                   NaN                             NaN
# 19                   NaN  PHTO SCHOOL ZN SPEED VIOLATION
# 20                   023  38-Failure to Display Muni Rec
# 21                  H 42  71A-Insp Sticker Expired (NYS)
# 22                     H                  14-No Standing
# 23                  25-A  75-No Match-Plate/Reg. Sticker
# 24                    10                  10-No Stopping
# 25                    09   69-Failure to Disp Muni Recpt
# 26                  03 3    21-No Parking (street clean)
# 27                  09 6  38-Failure to Display Muni Rec
# 28                  40 4                    50-Crosswalk
# 29                     F    21-No Parking (street clean)
# ..                   ...                             ...
# 970                   02           47-Double PKG-Midtown
# 971                  CC1                  14-No Standing
# 972                    D                  14-No Standing
# 973                 B 22    21-No Parking (street clean)
# 974                 08-A                 40-Fire Hydrant
# 975                   15    21-No Parking (street clean)
# 976                 W 31        20A-No Parking (Non-COM)
# 977                   57    21-No Parking (street clean)
# 978                 41 4           37-Expired Muni Meter
# 979                  NaN                             NaN
# 980                 10 6                  14-No Standing
# 981                  NaN                             NaN
# 982                   01  38-Failure to Display Muni Rec
# 983                  CC1  38-Failure to Display Muni Rec
# 984                    L                 40-Fire Hydrant
# 985                  NaN  PHTO SCHOOL ZN SPEED VIOLATION
# 986                 18 4                 40-Fire Hydrant
# 987                 H 21    46A-Double Parking (Non-COM)
# 988                    B                  14-No Standing
# 989                  NaN  PHTO SCHOOL ZN SPEED VIOLATION
# 990                    E    46A-Double Parking (Non-COM)
# 991                  NaN    FAILURE TO STOP AT RED LIGHT
# 992                 02 3  38-Failure to Display Muni Rec
# 993                  095                 40-Fire Hydrant
# 994                   56                  14-No Standing
# 995                   99                  14-No Standing
# 996                  NaN  PHTO SCHOOL ZN SPEED VIOLATION
# 997                 20 1                  14-No Standing
# 998                   11  38-Failure to Display Muni Rec
# 999                 W 41                 40-Fire Hydrant
#
#     No Standing or Stopping Violation Hydrant Violation  \
# 0                                 NaN               NaN
# 1                                 NaN               NaN
# 2                                 NaN               NaN
# 3                                 NaN               NaN
# 4                                 NaN               NaN
# 5                                 NaN               NaN
# 6                                 NaN               NaN
# 7                                 NaN               NaN
# 8                                 NaN               NaN
# 9                                 NaN               NaN
# 10                                NaN               NaN
# 11                                NaN               NaN
# 12                                NaN               NaN
# 13                                NaN               NaN
# 14                                NaN               NaN
# 15                                NaN               NaN
# 16                                NaN               NaN
# 17                                NaN               NaN
# 18                                NaN               NaN
# 19                                NaN               NaN
# 20                                NaN               NaN
# 21                                NaN               NaN
# 22                                NaN               NaN
# 23                                NaN               NaN
# 24                                NaN               NaN
# 25                                NaN               NaN
# 26                                NaN               NaN
# 27                                NaN               NaN
# 28                                NaN               NaN
# 29                                NaN               NaN
# ..                                ...               ...
# 970                               NaN               NaN
# 971                               NaN               NaN
# 972                               NaN               NaN
# 973                               NaN               NaN
# 974                               NaN               NaN
# 975                               NaN               NaN
# 976                               NaN               NaN
# 977                               NaN               NaN
# 978                               NaN               NaN
# 979                               NaN               NaN
# 980                               NaN               NaN
# 981                               NaN               NaN
# 982                               NaN               NaN
# 983                               NaN               NaN
# 984                               NaN               NaN
# 985                               NaN               NaN
# 986                               NaN               NaN
# 987                               NaN               NaN
# 988                               NaN               NaN
# 989                               NaN               NaN
# 990                               NaN               NaN
# 991                               NaN               NaN
# 992                               NaN               NaN
# 993                               NaN               NaN
# 994                               NaN               NaN
# 995                               NaN               NaN
# 996                               NaN               NaN
# 997                               NaN               NaN
# 998                               NaN               NaN
# 999                               NaN               NaN
#
#     Double Parking Violation
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# 5                        NaN
# 6                        NaN
# 7                        NaN
# 8                        NaN
# 9                        NaN
# 10                       NaN
# 11                       NaN
# 12                       NaN
# 13                       NaN
# 14                       NaN
# 15                       NaN
# 16                       NaN
# 17                       NaN
# 18                       NaN
# 19                       NaN
# 20                       NaN
# 21                       NaN
# 22                       NaN
# 23                       NaN
# 24                       NaN
# 25                       NaN
# 26                       NaN
# 27                       NaN
# 28                       NaN
# 29                       NaN
# ..                       ...
# 970                      NaN
# 971                      NaN
# 972                      NaN
# 973                      NaN
# 974                      NaN
# 975                      NaN
# 976                      NaN
# 977                      NaN
# 978                      NaN
# 979                      NaN
# 980                      NaN
# 981                      NaN
# 982                      NaN
# 983                      NaN
# 984                      NaN
# 985                      NaN
# 986                      NaN
# 987                      NaN
# 988                      NaN
# 989                      NaN
# 990                      NaN
# 991                      NaN
# 992                      NaN
# 993                      NaN
# 994                      NaN
# 995                      NaN
# 996                      NaN
# 997                      NaN
# 998                      NaN
# 999                      NaN
#
# [1000 rows x 43 columns]
#       Summons Number  Plate ID Registration State Plate Type  Issue Date  \
# 0         5092469481   GZH7067                 NY        PAS  07/10/2016
# 1         5092451658   GZH7067                 NY        PAS  07/08/2016
# 2         4006265037   FZX9232                 NY        PAS  08/23/2016
# 3         8478629828   66623ME                 NY        COM  06/14/2017
# 4         7868300310   37033JV                 NY        COM  11/21/2016
# 5         5096917368   FZD8593                 NY        PAS  06/13/2017
# 6         1413609545    X20DCM                 NJ        PAS  08/03/2016
# 7         4628525523    326SF9                 MA        PAS  12/21/2016
# 8         4627113330   HCA5464                 NY        OMS  11/21/2016
# 9         4006478550   VAD7274                 VA        PAS  10/05/2016
# 10        1407740258   2513JMG                 NY        COM  01/11/2017
# 11        8009901763   13657MD                 NY        COM  09/27/2016
# 12        4625926610  N102911C                 NY        OMT  10/27/2016
# 13        1416492320   FGR5997                 NY        PAS  09/30/2016
# 14        1413656420  T672371C                 NY        PAS  02/04/2017
# 15        7959486440   GYF2052                 NY        PAS  07/07/2016
# 16        5093620865   AD80228                 AZ        PAS  09/24/2016
# 17        8480309064   51771JW                 NY        COM  01/26/2017
# 18        1416638830    GLP367                 NY        PAS  04/30/2017
# 19        4630524241    HJBP29                 FL        PAS  02/03/2017
# 20        8505131836   87155MA                 NY        COM  05/27/2017
# 21        8472853342   HJN6543                 NY        PAS  10/04/2016
# 22        8513520615   77026MG                 NY        COM  05/31/2017
# 23        8556155431   HFB9919                 NY        PAS  05/26/2017
# 24        8483087236   76822MH                 NY        COM  05/19/2017
# 25        8513914599   65572JU                 NY        COM  06/09/2017
# 26        8344027755   GUP8589                 NY        PAS  12/07/2016
# 27        8040135217   GTV5924                 NY        PAS  11/19/2016
# 28        8466021980   GSC6098                 NY        PAS  12/27/2016
# 29        8357020770    Y56DLT                 NJ        PAS  01/20/2017
# ...              ...       ...                ...        ...         ...
# 1970      8509731652   HCM3103                 NY        OMS  05/19/2017
# 1971      8536512969   GWG7558                 NY        PAS  04/27/2017
# 1972      4629184090   44290MH                 NY        COM  01/09/2017
# 1973      4635130230   HNH7819                 NY        PAS  06/15/2017
# 1974      8523160360   HFY7644                 NY        PAS  04/11/2017
# 1975      7802483554   3HC487M                 MA        PAS  10/18/2016
# 1976      7793451430   HLD7424                 NY        PAS  03/18/2017
# 1977      7761584631   ZZ35900                 IL        PAS  12/20/2016
# 1978      8050561343   63046MA                 NY        COM  10/26/2016
# 1979      8482974543    671LEU                 CT        PAS  05/20/2017
# 1980      7491638843   GVG4819                 NY        PAS  06/06/2017
# 1981      4631348562    EAFY11                 FL        PAS  03/03/2017
# 1982      8546321462   72770MD                 NY        COM  06/20/2017
# 1983      1417140306    AT439M                 NJ        PAS  02/13/2017
# 1984      8175564805   DSX6049                 NY        PAS  01/25/2017
# 1985      8482054120   63014JM                 NY        COM  01/17/2017
# 1986      8508669252    628531                 NY        PAS  04/01/2017
# 1987      8518725770   HBE8361                 NY        PAS  06/26/2017
# 1988      8544890039   GRU3398                 NY        PAS  06/14/2017
# 1989      8145020451   HJK9979                 NY        PAS  01/17/2017
# 1990      7792734018   CRJ5218                 NY        PAS  09/16/2016
# 1991      8343078196   FCM3750                 NY        PAS  01/30/2017
# 1992      8550505912   HNF5112                 NY        PAS  05/11/2017
# 1993      8470716724    XZ254Y                 NJ        PAS  09/28/2016
# 1994      8349009410   82808ME                 NY        COM  07/05/2016
# 1995      8237541080   HDE6915                 NY        PAS  03/27/2017
# 1996      8511500900    L15036                 CT        COM  02/15/2017
# 1997      8065010489    EXCY19                 FL        PAS  07/27/2016
# 1998      8513256158    AR713C                 NJ        PAS  03/24/2017
# 1999      8543151223   EVP8278                 NY        PAS  04/11/2017
#
#       Violation Code Vehicle Body Type Vehicle Make Issuing Agency  \
# 0                  7              SUBN        TOYOT              V
# 1                  7              SUBN        TOYOT              V
# 2                  5              SUBN         FORD              V
# 3                 47              REFG        MITSU              T
# 4                 69              DELV        INTER              T
# 5                  7              SUBN        ME/BE              V
# 6                 40               SDN        TOYOT              P
# 7                 36                UT          BMW              V
# 8                 36              SUBN        DODGE              V
# 9                  5                4D          BMW              V
# 10                78              DELV        FRUEH              P
# 11                19              DELV        KENWO              T
# 12                36               VAN         FORD              V
# 13                21               SDN        NISSA              P
# 14                40              TAXI        TOYOT              P
# 15                71              4DSD        VOLKS              T
# 16                 7                TK         FORD              V
# 17                64               VAN        INTER              T
# 18                20              SUBN        DODGE              P
# 19                36                4D          BMW              V
# 20                38               VAN        CHEVR              T
# 21                71              2DSD        LINCO              T
# 22                14              TRAC        VOLVO              T
# 23                75              4DSD        DODGE              T
# 24                10              DELV          HIN              T
# 25                69               VAN         FORD              T
# 26                21              SUBN        NISSA              T
# 27                38              SUBN        HONDA              T
# 28                50              4DSD        NISSA              T
# 29                21              4DSD        CHEVR              T
# ...              ...               ...          ...            ...
# 1970              20              SUBN        DODGE              T
# 1971              21              SUBN        CHRYS              T
# 1972              36              PICK         FORD              V
# 1973              36              4DSD        HYUND              V
# 1974              46              4DSD        DODGE              T
# 1975              14              4DSD        HONDA              T
# 1976              38              4DSD        TOYOT              T
# 1977              21              SUBN         FORD              T
# 1978              37              DELV        HYUND              T
# 1979              14              SUBN          BMW              T
# 1980              20              SUBN        SUBAR              T
# 1981              36                4D        JAGUA              V
# 1982              38               VAN         FORD              T
# 1983              19              FLAT        FRUEH              P
# 1984              20              4DSD        NISSA              T
# 1985              42              DELV          GMC              T
# 1986              20              SUBN        TOYOT              T
# 1987              19              SUBN        HONDA              T
# 1988              46              4DSD         AUDI              T
# 1989              21              4DSD        VOLKS              T
# 1990              37              SUBN        DODGE              T
# 1991              68              SUBN         JEEP              T
# 1992              21              SUBN        TOYOT              T
# 1993              19              DELV        FRUEH              T
# 1994              24              DELV        FRUEH              T
# 1995              38              4DSD          BMW              T
# 1996              46               NaN        ISUZU              T
# 1997              16              4DSD        NISSA              T
# 1998              46              DELV        INTER              T
# 1999              20              SUBN        LEXUS              T
#
#       Street Code1           ...             Vehicle Color  \
# 0                0           ...                        GY
# 1                0           ...                        GY
# 2                0           ...                        BK
# 3            10610           ...                        WH
# 4            10510           ...                     WHITE
# 5                0           ...                        WH
# 6            54070           ...                     WHITE
# 7                0           ...                       NaN
# 8                0           ...                        BK
# 9                0           ...                       BLK
# 10               0           ...                     WHITE
# 11           10510           ...                        RD
# 12               0           ...                        WH
# 13           53620           ...                       TAN
# 14           59630           ...                       BLK
# 15           70407           ...                        GY
# 16               0           ...                       NaN
# 17           17850           ...                     BROWN
# 18           17650           ...                       BLK
# 19               0           ...                       SIL
# 20           27050           ...                        WH
# 21           39680           ...                        RD
# 22           15710           ...                     GREEN
# 23           10090           ...                        GY
# 24           10810           ...                        WH
# 25           10110           ...                        WH
# 26           67730           ...                     SILVE
# 27           13610           ...                        WH
# 28               0           ...                        WH
# 29           60810           ...                     BLACK
# ...            ...           ...                       ...
# 1970         29890           ...                        BK
# 1971         54000           ...                     SILVE
# 1972             0           ...                      WHBL
# 1973             0           ...                        WH
# 1974         22920           ...                        GY
# 1975         18790           ...                     WHITE
# 1976          7790           ...                        BL
# 1977         24440           ...                     GREEN
# 1978         10110           ...                        BR
# 1979         34890           ...                     BLACK
# 1980         39595           ...                        TN
# 1981             0           ...                       MUL
# 1982         14080           ...                        WH
# 1983         52930           ...                        GR
# 1984          9130           ...                        GY
# 1985         34570           ...                     BROWN
# 1986         20490           ...                       LTG
# 1987         13610           ...                        BL
# 1988          7030           ...                        BK
# 1989         77150           ...                        BK
# 1990          5940           ...                        TN
# 1991         38130           ...                        BK
# 1992             0           ...                        GY
# 1993         10410           ...                     WHITE
# 1994         25010           ...                     WHITE
# 1995         19340           ...                        BL
# 1996         37130           ...                       NaN
# 1997         17870           ...                     BLACK
# 1998         11710           ...                     WHITE
# 1999          5580           ...                        WH
#
#       Unregistered Vehicle?  Vehicle Year  Meter Number  Feet From Curb  \
# 0                       NaN          2001           NaN               0
# 1                       NaN          2001           NaN               0
# 2                       NaN          2004           NaN               0
# 3                       NaN          2007           NaN               0
# 4                       NaN          2007           NaN               0
# 5                       NaN          2012           NaN               0
# 6                       0.0             0             -               1
# 7                       NaN          2001           NaN               0
# 8                       NaN          2016           NaN               0
# 9                       NaN          2008           NaN               0
# 10                      0.0          2015             -               0
# 11                      NaN          2013           NaN               0
# 12                      NaN          2008           NaN               0
# 13                      0.0             0             -               0
# 14                      0.0          2015             -               0
# 15                      NaN          2012           NaN               0
# 16                      NaN          2009           NaN               0
# 17                      NaN          2007           NaN               0
# 18                      0.0          2009             -               0
# 19                      NaN          2009           NaN               0
# 20                      NaN          2016           NaN               0
# 21                      NaN          1989           NaN               0
# 22                      NaN          2016           NaN               0
# 23                      NaN          2013           NaN               0
# 24                      NaN          2012           NaN               0
# 25                      NaN          2009           NaN               0
# 26                      NaN          2008           NaN               0
# 27                      NaN          2014           NaN               0
# 28                      NaN          2009           NaN               0
# 29                      NaN             0           NaN               0
# ...                     ...           ...           ...             ...
# 1970                    NaN          2017           NaN               0
# 1971                    NaN          2017           NaN               0
# 1972                    NaN          2016           NaN               0
# 1973                    NaN          2010           NaN               0
# 1974                    NaN          2015           NaN               0
# 1975                    NaN             0           NaN               0
# 1976                    NaN          1999           NaN               0
# 1977                    NaN             0           NaN               0
# 1978                    NaN          2013      126-4950               0
# 1979                    NaN             0           NaN               0
# 1980                    NaN          2014           NaN               0
# 1981                    NaN          2012           NaN               0
# 1982                    NaN          2013           NaN               0
# 1983                    0.0             0             -               0
# 1984                    NaN          2005           NaN               0
# 1985                    NaN          1987      144-3980               0
# 1986                    NaN          2002           NaN               0
# 1987                    NaN          2001           NaN               0
# 1988                    NaN          2014           NaN               0
# 1989                    NaN          2016           NaN               0
# 1990                    NaN          2004      438-3118               0
# 1991                    NaN          2014           NaN               0
# 1992                    NaN          2004           NaN               0
# 1993                    NaN             0           NaN               0
# 1994                    NaN          2006           NaN               0
# 1995                    NaN          2003           NaN               0
# 1996                    NaN             0           NaN               0
# 1997                    NaN             0           NaN               0
# 1998                    NaN             0           NaN               0
# 1999                    NaN          2015           NaN               0
#
#       Violation Post Code           Violation Description  \
# 0                     NaN    FAILURE TO STOP AT RED LIGHT
# 1                     NaN    FAILURE TO STOP AT RED LIGHT
# 2                     NaN              BUS LANE VIOLATION
# 3                      04           47-Double PKG-Midtown
# 4                    31 6   69-Failure to Disp Muni Recpt
# 5                     NaN    FAILURE TO STOP AT RED LIGHT
# 6                     NaN                             NaN
# 7                     NaN  PHTO SCHOOL ZN SPEED VIOLATION
# 8                     NaN  PHTO SCHOOL ZN SPEED VIOLATION
# 9                     NaN              BUS LANE VIOLATION
# 10                    NaN                             NaN
# 11                   01 9          19-No Stand (bus stop)
# 12                    NaN  PHTO SCHOOL ZN SPEED VIOLATION
# 13                    NaN                             NaN
# 14                    NaN                             NaN
# 15                   C-PM   71-Insp. Sticker Missing (NYS
# 16                    NaN    FAILURE TO STOP AT RED LIGHT
# 17                     06   64-No STD Ex Con/DPL, D/S Dec
# 18                    NaN                             NaN
# 19                    NaN  PHTO SCHOOL ZN SPEED VIOLATION
# 20                    023  38-Failure to Display Muni Rec
# 21                   H 42  71A-Insp Sticker Expired (NYS)
# 22                      H                  14-No Standing
# 23                   25-A  75-No Match-Plate/Reg. Sticker
# 24                     10                  10-No Stopping
# 25                     09   69-Failure to Disp Muni Recpt
# 26                   03 3    21-No Parking (street clean)
# 27                   09 6  38-Failure to Display Muni Rec
# 28                   40 4                    50-Crosswalk
# 29                      F    21-No Parking (street clean)
# ...                   ...                             ...
# 1970                   61        20A-No Parking (Non-COM)
# 1971                    W    21-No Parking (street clean)
# 1972                  NaN  PHTO SCHOOL ZN SPEED VIOLATION
# 1973                  NaN  PHTO SCHOOL ZN SPEED VIOLATION
# 1974                   11    46A-Double Parking (Non-COM)
# 1975                 01 8                  14-No Standing
# 1976                   24  38-Failure to Display Muni Rec
# 1977                 14 4    21-No Parking (street clean)
# 1978                  CC1           37-Expired Muni Meter
# 1979                   45                  14-No Standing
# 1980                   01        20A-No Parking (Non-COM)
# 1981                  NaN  PHTO SCHOOL ZN SPEED VIOLATION
# 1982                   02  38-Failure to Display Muni Rec
# 1983                  NaN                             NaN
# 1984                   43        20A-No Parking (Non-COM)
# 1985                   08  42-Exp. Muni-Mtr (Com. Mtr. Z)
# 1986                   95        20A-No Parking (Non-COM)
# 1987                   05          19-No Stand (bus stop)
# 1988                    J    46A-Double Parking (Non-COM)
# 1989                    H    21-No Parking (street clean)
# 1990                 C 41           37-Expired Muni Meter
# 1991                    T  68-Not Pkg. Comp. w Psted Sign
# 1992                   43    21-No Parking (street clean)
# 1993                 17 6          19-No Stand (bus stop)
# 1994                 64 1    24-No Parking (exc auth veh)
# 1995                   40  38-Failure to Display Muni Rec
# 1996                    M  46B-Double Parking (Com-100Ft)
# 1997                 17 7    16A-No Std (Com Veh) Non-COM
# 1998                   48  46B-Double Parking (Com-100Ft)
# 1999                   56        20A-No Parking (Non-COM)
#
# ...
# 25                       NaN          2009           NaN               0
# 26                       NaN          2008           NaN               0
# 27                       NaN          2014           NaN               0
# 28                       NaN          2009           NaN               0
# 29                       NaN             0           NaN               0
# ...                      ...           ...           ...             ...
# 83970                    NaN          2011           NaN               0
# 83971                    NaN          2012           NaN               0
# 83972                    NaN          2015           NaN               0
# 83973                    NaN          2014           NaN               0
# 83974                    NaN          2005           NaN               0
# 83975                    NaN             0           NaN               0
# 83976                    NaN             0           NaN               0
# 83977                    NaN          2002           NaN               0
# 83978                    NaN          1998           NaN               0
# 83979                    NaN          2012           NaN               0
# 83980                    NaN          2016           NaN               0
# 83981                    NaN          2011           NaN               0
# 83982                    NaN          2008           NaN               0
# 83983                    NaN          2005           NaN               0
# 83984                    NaN          2006           NaN               0
# 83985                    NaN          2013           NaN               0
# 83986                    NaN          2014           NaN               0
# 83987                    NaN             0           NaN               0
# 83988                    NaN          2012           NaN               0
# 83989                    NaN          2014           NaN               0
# 83990                    NaN          2015           NaN               0
# 83991                    NaN             0           NaN               0
# 83992                    NaN             0           NaN               0
# 83993                    NaN          2007           NaN               0
# 83994                    NaN          2004           NaN               0
# 83995                    NaN          2015           NaN               0
# 83996                    NaN             0           NaN               0
# 83997                    NaN          2016           NaN               0
# 83998                    NaN          2016           NaN               0
# 83999                    NaN          1999           NaN               0
#
#        Violation Post Code           Violation Description  \
# 0                      NaN    FAILURE TO STOP AT RED LIGHT
# 1                      NaN    FAILURE TO STOP AT RED LIGHT
# 2                      NaN              BUS LANE VIOLATION
# 3                       04           47-Double PKG-Midtown
# 4                     31 6   69-Failure to Disp Muni Recpt
# 5                      NaN    FAILURE TO STOP AT RED LIGHT
# 6                      NaN                             NaN
# 7                      NaN  PHTO SCHOOL ZN SPEED VIOLATION
# 8                      NaN  PHTO SCHOOL ZN SPEED VIOLATION
# 9                      NaN              BUS LANE VIOLATION
# 10                     NaN                             NaN
# 11                    01 9          19-No Stand (bus stop)
# 12                     NaN  PHTO SCHOOL ZN SPEED VIOLATION
# 13                     NaN                             NaN
# 14                     NaN                             NaN
# 15                    C-PM   71-Insp. Sticker Missing (NYS
# 16                     NaN    FAILURE TO STOP AT RED LIGHT
# 17                      06   64-No STD Ex Con/DPL, D/S Dec
# 18                     NaN                             NaN
# 19                     NaN  PHTO SCHOOL ZN SPEED VIOLATION
# 20                     023  38-Failure to Display Muni Rec
# 21                    H 42  71A-Insp Sticker Expired (NYS)
# 22                       H                  14-No Standing
# 23                    25-A  75-No Match-Plate/Reg. Sticker
# 24                      10                  10-No Stopping
# 25                      09   69-Failure to Disp Muni Recpt
# 26                    03 3    21-No Parking (street clean)
# 27                    09 6  38-Failure to Display Muni Rec
# 28                    40 4                    50-Crosswalk
# 29                       F    21-No Parking (street clean)
# ...                    ...                             ...
# 83970                 L 41        20A-No Parking (Non-COM)
# 83971                   09  38-Failure to Display Muni Rec
# 83972                 11 4          19-No Stand (bus stop)
# 83973                  NaN  PHTO SCHOOL ZN SPEED VIOLATION
# 83974                  NaN  PHTO SCHOOL ZN SPEED VIOLATION
# 83975                 11 3    21-No Parking (street clean)
# 83976                 C-AM                  14-No Standing
# 83977                   56                 40-Fire Hydrant
# 83978                  NaN    FAILURE TO STOP AT RED LIGHT
# 83979                  NaN    FAILURE TO STOP AT RED LIGHT
# 83980                 14 2  70A-Reg. Sticker Expired (NYS)
# 83981                   17        20A-No Parking (Non-COM)
# 83982                 02-A                  14-No Standing
# 83983                  009  70A-Reg. Sticker Expired (NYS)
# 83984                  CC1               74B-Covered Plate
# 83985                 99 6   69-Failure to Disp Muni Recpt
# 83986                 C 77             09-Blocking the Box
# 83987                   04          19-No Stand (bus stop)
# 83988                 02 7  71A-Insp Sticker Expired (NYS)
# 83989                 C-PM  71A-Insp Sticker Expired (NYS)
# 83990                   18                  14-No Standing
# 83991                   01  38-Failure to Display Muni Rec
# 83992                   01    31-No Stand (Com. Mtr. Zone)
# 83993                    P                 40-Fire Hydrant
# 83994                 01 7    21-No Parking (street clean)
# 83995                  NaN    FAILURE TO STOP AT RED LIGHT
# 83996                    G    24-No Parking (exc auth veh)
# 83997                  NaN  PHTO SCHOOL ZN SPEED VIOLATION
# 83998                  NaN  PHTO SCHOOL ZN SPEED VIOLATION
# 83999                 J 41        20A-No Parking (Non-COM)
#
#       No Standing or Stopping Violation Hydrant Violation  \
# 0                                   NaN               NaN
# 1                                   NaN               NaN
# 2                                   NaN               NaN
# 3                                   NaN               NaN
# 4                                   NaN               NaN
# 5                                   NaN               NaN
# 6                                   NaN               NaN
# 7                                   NaN               NaN
# 8                                   NaN               NaN
# 9                                   NaN               NaN
# 10                                  NaN               NaN
# 11                                  NaN               NaN
# 12                                  NaN               NaN
# 13                                  NaN               NaN
# 14                                  NaN               NaN
# 15                                  NaN               NaN
# 16                                  NaN               NaN
# 17                                  NaN               NaN
# 18                                  NaN               NaN
# 19                                  NaN               NaN
# 20                                  NaN               NaN
# 21                                  NaN               NaN
# 22                                  NaN               NaN
# 23                                  NaN               NaN
# 24                                  NaN               NaN
# 25                                  NaN               NaN
# 26                                  NaN               NaN
# 27                                  NaN               NaN
# 28                                  NaN               NaN
# 29                                  NaN               NaN
# ...                                 ...               ...
# 83970                               NaN               NaN
# 83971                               NaN               NaN
# 83972                               NaN               NaN
# 83973                               NaN               NaN
# 83974                               NaN               NaN
# 83975                               NaN               NaN
# 83976                               NaN               NaN
# 83977                               NaN               NaN
# 83978                               NaN               NaN
# 83979                               NaN               NaN
# 83980                               NaN               NaN
# 83981                               NaN               NaN
# 83982                               NaN               NaN
# 83983                               NaN               NaN
# 83984                               NaN               NaN
# 83985                               NaN               NaN
# 83986                               NaN               NaN
# 83987                               NaN               NaN
# 83988                               NaN               NaN
# 83989                               NaN               NaN
# 83990                               NaN               NaN
# 83991                               NaN               NaN
# 83992                               NaN               NaN
# 83993                               NaN               NaN
# 83994                               NaN               NaN
# 83995                               NaN               NaN
# 83996                               NaN               NaN
# 83997                               NaN               NaN
# 83998                               NaN               NaN
# 83999                               NaN               NaN
#
#       Double Parking Violation
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
# 5                          NaN
# 6                          NaN
# 7                          NaN
# 8                          NaN
# 9                          NaN
# 10                         NaN
# 11                         NaN
# 12                         NaN
# 13                         NaN
# 14                         NaN
# 15                         NaN
# 16                         NaN
# 17                         NaN
# 18                         NaN
# 19                         NaN
# 20                         NaN
# 21                         NaN
# 22                         NaN
# 23                         NaN
# 24                         NaN
# 25                         NaN
# 26                         NaN
# 27                         NaN
# 28                         NaN
# 29                         NaN
# ...                        ...
# 83970                      NaN
# 83971                      NaN
# 83972                      NaN
# 83973                      NaN
# 83974                      NaN
# 83975                      NaN
# 83976                      NaN
# 83977                      NaN
# 83978                      NaN
# 83979                      NaN
# 83980                      NaN
# 83981                      NaN
# 83982                      NaN
# 83983                      NaN
# 83984                      NaN
# 83985                      NaN
# 83986                      NaN
# 83987                      NaN
# 83988                      NaN
# 83989                      NaN
# 83990                      NaN
# 83991                      NaN
# 83992                      NaN
# 83993                      NaN
# 83994                      NaN
# 83995                      NaN
# 83996                      NaN
# 83997                      NaN
# 83998                      NaN
# 83999                      NaN
#
# [84000 rows x 43 columns]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-35f804c5d643> in <module>()
#       3 data = pd.DataFrame()
#       4 for chunk in reader:
# ----> 5     data = pd.concat([data, chunk])
#       6     print(data)
#       7
#
# /opt/conda/lib/python3.6/site-packages/pandas/tools/merge.py in concat(objs, axis, join, join_axes, ignore_index, keys, levels, names, verify_integrity, copy)
#    1449                        keys=keys, levels=levels, names=names,
#    1450                        verify_integrity=verify_integrity,
# -> 1451                        copy=copy)
#    1452     return op.get_result()
#    1453
#
# /opt/conda/lib/python3.6/site-packages/pandas/tools/merge.py in __init__(self, objs, axis, join, join_axes, keys, levels, names, ignore_index, verify_integrity, copy)
#    1509
#    1510             # consolidate
# -> 1511             obj.consolidate(inplace=True)
#    1512             ndims.add(obj.ndim)
#    1513
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/generic.py in consolidate(self, inplace)
#    2817         """
#    2818         if inplace:
# -> 2819             self._consolidate_inplace()
#    2820         else:
#    2821             f = lambda: self._data.consolidate()
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/generic.py in _consolidate_inplace(self)
#    2799             self._data = self._data.consolidate()
#    2800
# -> 2801         self._protect_consolidate(f)
#    2802
#    2803     def consolidate(self, inplace=False):
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/generic.py in _protect_consolidate(self, f)
#    2788         """
#    2789         blocks_before = len(self._data.blocks)
# -> 2790         result = f()
#    2791         if len(self._data.blocks) != blocks_before:
#    2792             self._clear_item_cache()
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/generic.py in f()
#    2797
#    2798         def f():
# -> 2799             self._data = self._data.consolidate()
#    2800
#    2801         self._protect_consolidate(f)
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/internals.py in consolidate(self)
#    3524         bm = self.__class__(self.blocks, self.axes)
#    3525         bm._is_consolidated = False
# -> 3526         bm._consolidate_inplace()
#    3527         return bm
#    3528
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/internals.py in _consolidate_inplace(self)
#    3529     def _consolidate_inplace(self):
#    3530         if not self.is_consolidated():
# -> 3531             self.blocks = tuple(_consolidate(self.blocks))
#    3532             self._is_consolidated = True
#    3533             self._known_consolidated = True
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/internals.py in _consolidate(blocks)
#    4521     for (_can_consolidate, dtype), group_blocks in grouper:
#    4522         merged_blocks = _merge_blocks(list(group_blocks), dtype=dtype,
# -> 4523                                       _can_consolidate=_can_consolidate)
#    4524         new_blocks = _extend_blocks(merged_blocks, new_blocks)
#    4525     return new_blocks
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/internals.py in _merge_blocks(blocks, dtype, _can_consolidate)
#    4545         argsort = np.argsort(new_mgr_locs)
#    4546         new_values = new_values[argsort]
# -> 4547         new_mgr_locs = new_mgr_locs[argsort]
#    4548
#    4549         return make_block(new_values, fastpath=True, placement=new_mgr_locs)
#
# KeyboardInterrupt:

# %%
#Load n lines of dataset
n = 1000000
data = pd.read_csv(path, nrows=n)
#print(data['Issue Date'])
#print(data)
print('First ' + str(n) + ' rows loaded!')
# Out:
# /opt/conda/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2728: DtypeWarning: Columns (17,18,20,21,22,23,29,30,31,32,36,38,39) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# First 1000000 rows loaded!

# %%
#get overview of the first 5 rows of the dataset
data.head()
# Out:
#    Summons Number Plate ID Registration State Plate Type  Issue Date  \
# 0      1363745270  GGY6450                 99        PAS  07/09/2015
# 1      1363745293   KXD355                 SC        PAS  07/09/2015
# 2      1363745438  JCK7576                 PA        PAS  07/09/2015
# 3      1363745475  GYK7658                 NY        OMS  07/09/2015
# 4      1363745487  GMT8141                 NY        PAS  07/09/2015
#
#    Violation Code Vehicle Body Type Vehicle Make Issuing Agency  Street Code1  \
# 0              46               SDN        HONDA              P             0
# 1              21              SUBN        CHEVR              P         55730
# 2              21               SDN        ME/BE              P         42730
# 3              21              SUBN        NISSA              P         58130
# 4              21               P-U        LINCO              P         58130
#
#             ...             Vehicle Color  Unregistered Vehicle?  \
# 0           ...                     WHITE                    0.0
# 1           ...                       RED                    0.0
# 2           ...                     WHITE                    0.0
# 3           ...                        BK                    0.0
# 4           ...                       BLK                    0.0
#
#    Vehicle Year  Meter Number  Feet From Curb  Violation Post Code  \
# 0          2010             -               0                  NaN
# 1             0             -               0                  NaN
# 2             0             -               0                  NaN
# 3          2015             -               0                  NaN
# 4          2006             -               0                  NaN
#
#    Violation Description No Standing or Stopping Violation Hydrant Violation  \
# 0                    NaN                               NaN               NaN
# 1                    NaN                               NaN               NaN
# 2                    NaN                               NaN               NaN
# 3                    NaN                               NaN               NaN
# 4                    NaN                               NaN               NaN
#
#   Double Parking Violation
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
#
# [5 rows x 43 columns]

# %%
#OLD read data.csv
import csv

with open(path, 'r') as f:
    reader = csv.reader(f)
    data = list(reader)


data.head()
print('Dataset loaded')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-151dd8295e24> in <module>()
#       4 with open('Parking_Violations_Issued_-_Fiscal_Year_2018.csv', 'r') as f:
#       5     reader = csv.reader(f)
# ----> 6     data = list(reader)
#       7
#       8
#
# /opt/conda/lib/python3.6/codecs.py in decode(self, input, final)
#     316         raise NotImplementedError
#     317
# --> 318     def decode(self, input, final=False):
#     319         # decode input (taking the buffer into account)
#     320         data = self.buffer + input
#
# KeyboardInterrupt:

# %%
#data = np.array(json[['street_name', 'house_number', 'issue_date']]) ->for json
data = np.array(data[['Street Name','House Number','Issue Date']])

#date = '2015-08-09'#date of the ticket records ->for json
#dateformat = date + 'T00:00:00.000'#for equals ->for json

dateformat = '07/09/2015'#date you want to extract

count = 0
delTuple = []#array of not needed tuples
for x in data:
    
    if dateformat not in x[2]: 
        #print(x[2] + ' ' + dateformat)
        delTuple.append(count)
        
    count+=1
    continue
    
print('Tuples deleted: ' + str(len(delTuple)))

#print(delTuple)#print Tuples to be deleted

dataTime = np.delete(data, (delTuple), axis=0)#delete not needed tuples

#print(dataTime)#print new array

data = np.delete(dataTime, ([2]), axis=1)#delete date row

data = [[x[0], x[1]] for x in data] #prepare data for maps
datasetCount = len(data)
#datasetCount = 100 #optional: reduce dataset to n rows
data = data[:datasetCount]
print('Data has ' + str(datasetCount) + ' rows')
#print(data)
# Out:
# Tuples deleted: 964326
# Data has 35674 rows

# %%
from ipywidgets import FloatProgress
from IPython.display import display

f = FloatProgress(min=0, max=datasetCount) #Successful
#e = 0 #Errors

# %%
import googlemaps
import json

gmapsAPI = googlemaps.Client(key=apikey)

def geocode( x ):
    geocode = gmapsAPI.geocode(str(x) + 'New York' + 'USA')
    geocode = np.array(geocode)

    global e
    try:
        x[0] = geocode[0].get('geometry').get('location').get('lat')
        x[1] = geocode[0].get('geometry').get('location').get('lng')
    except IndexError:
        x[0] = 0
        x[1] = 0
        e+=1
    f.value += 1
    print('Successful: ' + str(f.value) + '/' + str(datasetCount) + ' Errors: ' + str(e), end='\r')
    return x

# %%
f.value = 0
display(f)
e = 0
print('Successful: ' + str(f.value) + '/' + str(datasetCount) + ' Errors: ' + str(e), end='\r')

data = [geocode(x) for x in data]

print(' Finished!')
# Out:
# FloatProgress(value=0.0, max=35674.0)
# Successful: 2135.0/35674 Errors: 90
# ---------------------------------------------------------------------------
# _RetriableRequest                         Traceback (most recent call last)
# /opt/conda/lib/python3.6/site-packages/googlemaps/client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     252             else:
# --> 253                 result = self._get_body(response)
#     254             self.sent_times.append(time.time())
#
# /opt/conda/lib/python3.6/site-packages/googlemaps/client.py in _get_body(self, response)
#     275         if api_status == "OVER_QUERY_LIMIT":
# --> 276             raise googlemaps.exceptions._RetriableRequest()
#     277
#
# _RetriableRequest:
#
# During handling of the above exception, another exception occurred:
#
# _RetriableRequest                         Traceback (most recent call last)
# /opt/conda/lib/python3.6/site-packages/googlemaps/client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     252             else:
# --> 253                 result = self._get_body(response)
#     254             self.sent_times.append(time.time())
#
# /opt/conda/lib/python3.6/site-packages/googlemaps/client.py in _get_body(self, response)
#     275         if api_status == "OVER_QUERY_LIMIT":
# --> 276             raise googlemaps.exceptions._RetriableRequest()
#     277
#
# _RetriableRequest:
#
# During handling of the above exception, another exception occurred:
#
# _RetriableRequest                         Traceback (most recent call last)
# /opt/conda/lib/python3.6/site-packages/googlemaps/client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     252             else:
# --> 253                 result = self._get_body(response)
#     254             self.sent_times.append(time.time())
#
# /opt/conda/lib/python3.6/site-packages/googlemaps/client.py in _get_body(self, response)
#     275         if api_status == "OVER_QUERY_LIMIT":
# --> 276             raise googlemaps.exceptions._RetriableRequest()
#     277
#
# _RetriableRequest:
#
# During handling of the above exception, another exception occurred:
#
# _RetriableRequest                         Traceback (most recent call last)
# /opt/conda/lib/python3.6/site-packages/googlemaps/client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     252             else:
# --> 253                 result = self._get_body(response)
#     254             self.sent_times.append(time.time())
#
# /opt/conda/lib/python3.6/site-packages/googlemaps/client.py in _get_body(self, response)
#     275         if api_status == "OVER_QUERY_LIMIT":
# --> 276             raise googlemaps.exceptions._RetriableRequest()
#     277
#
# _RetriableRequest:
#
# During handling of the above exception, another exception occurred:
#
# _RetriableRequest                         Traceback (most recent call last)
# /opt/conda/lib/python3.6/site-packages/googlemaps/client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     252             else:
# --> 253                 result = self._get_body(response)
#     254             self.sent_times.append(time.time())
#
# /opt/conda/lib/python3.6/site-packages/googlemaps/client.py in _get_body(self, response)
#     275         if api_status == "OVER_QUERY_LIMIT":
# --> 276             raise googlemaps.exceptions._RetriableRequest()
#     277
#
# _RetriableRequest:
#
# During handling of the above exception, another exception occurred:
#
# _RetriableRequest                         Traceback (most recent call last)
# /opt/conda/lib/python3.6/site-packages/googlemaps/client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     252             else:
# --> 253                 result = self._get_body(response)
#     254             self.sent_times.append(time.time())
#
# /opt/conda/lib/python3.6/site-packages/googlemaps/client.py in _get_body(self, response)
#     275         if api_status == "OVER_QUERY_LIMIT":
# --> 276             raise googlemaps.exceptions._RetriableRequest()
#     277
#
# _RetriableRequest:
#
# During handling of the above exception, another exception occurred:
#
# _RetriableRequest                         Traceback (most recent call last)
# /opt/conda/lib/python3.6/site-packages/googlemaps/client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     252             else:
# --> 253                 result = self._get_body(response)
#     254             self.sent_times.append(time.time())
#
# /opt/conda/lib/python3.6/site-packages/googlemaps/client.py in _get_body(self, response)
#     275         if api_status == "OVER_QUERY_LIMIT":
# --> 276             raise googlemaps.exceptions._RetriableRequest()
#     277
#
# _RetriableRequest:
#
# During handling of the above exception, another exception occurred:
#
# _RetriableRequest                         Traceback (most recent call last)
# /opt/conda/lib/python3.6/site-packages/googlemaps/client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     252             else:
# --> 253                 result = self._get_body(response)
#     254             self.sent_times.append(time.time())
#
# /opt/conda/lib/python3.6/site-packages/googlemaps/client.py in _get_body(self, response)
#     275         if api_status == "OVER_QUERY_LIMIT":
# --> 276             raise googlemaps.exceptions._RetriableRequest()
#     277
#
# _RetriableRequest:
#
# During handling of the above exception, another exception occurred:
#
# _RetriableRequest                         Traceback (most recent call last)
# /opt/conda/lib/python3.6/site-packages/googlemaps/client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     252             else:
# --> 253                 result = self._get_body(response)
#     254             self.sent_times.append(time.time())
#
# /opt/conda/lib/python3.6/site-packages/googlemaps/client.py in _get_body(self, response)
#     275         if api_status == "OVER_QUERY_LIMIT":
# --> 276             raise googlemaps.exceptions._RetriableRequest()
#     277
#
# _RetriableRequest:
#
# During handling of the above exception, another exception occurred:
#
# _RetriableRequest                         Traceback (most recent call last)
# /opt/conda/lib/python3.6/site-packages/googlemaps/client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     252             else:
# --> 253                 result = self._get_body(response)
#     254             self.sent_times.append(time.time())
#
# /opt/conda/lib/python3.6/site-packages/googlemaps/client.py in _get_body(self, response)
#     275         if api_status == "OVER_QUERY_LIMIT":
# --> 276             raise googlemaps.exceptions._RetriableRequest()
#     277
#
# _RetriableRequest:
#
# During handling of the above exception, another exception occurred:
#
# _RetriableRequest                         Traceback (most recent call last)
# /opt/conda/lib/python3.6/site-packages/googlemaps/client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     252             else:
# --> 253                 result = self._get_body(response)
#     254             self.sent_times.append(time.time())
#
# /opt/conda/lib/python3.6/site-packages/googlemaps/client.py in _get_body(self, response)
#     275         if api_status == "OVER_QUERY_LIMIT":
# --> 276             raise googlemaps.exceptions._RetriableRequest()
#     277
#
# _RetriableRequest:
#
# During handling of the above exception, another exception occurred:
#
# _RetriableRequest                         Traceback (most recent call last)
# /opt/conda/lib/python3.6/site-packages/googlemaps/client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     252             else:
# --> 253                 result = self._get_body(response)
#     254             self.sent_times.append(time.time())
#
# /opt/conda/lib/python3.6/site-packages/googlemaps/client.py in _get_body(self, response)
#     275         if api_status == "OVER_QUERY_LIMIT":
# --> 276             raise googlemaps.exceptions._RetriableRequest()
#     277
#
# _RetriableRequest:
#
# During handling of the above exception, another exception occurred:
#
# Timeout                                   Traceback (most recent call last)
# <ipython-input-8-b78a1dc77f9b> in <module>()
#       4 print('Successful: ' + str(f.value) + '/' + str(datasetCount) + ' Errors: ' + str(e), end='\r')
#       5
# ----> 6 data = [geocode(x) for x in data]
#       7
#       8 print(' Finished!')
#
# <ipython-input-8-b78a1dc77f9b> in <listcomp>(.0)
#       4 print('Successful: ' + str(f.value) + '/' + str(datasetCount) + ' Errors: ' + str(e), end='\r')
#       5
# ----> 6 data = [geocode(x) for x in data]
#       7
#       8 print(' Finished!')
#
# <ipython-input-7-e96af9c5ce21> in geocode(x)
#       5
#       6 def geocode( x ):
# ----> 7     geocode = gmapsAPI.geocode(str(x) + 'New York' + 'USA')
#       8     geocode = np.array(geocode)
#       9
#
# /opt/conda/lib/python3.6/site-packages/googlemaps/client.py in wrapper(*args, **kwargs)
#     354     def wrapper(*args, **kwargs):
#     355         args[0]._extra_params = kwargs.pop("extra_params", None)
# --> 356         result = func(*args, **kwargs)
#     357         try:
#     358             del args[0]._extra_params
#
# /opt/conda/lib/python3.6/site-packages/googlemaps/geocoding.py in geocode(client, address, components, bounds, region, language)
#      66         params["language"] = language
#      67
# ---> 68     return client._request("/maps/api/geocode/json", params)["results"]
#      69
#      70
#
# /opt/conda/lib/python3.6/site-packages/googlemaps/client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     258             return self._request(url, params, first_request_time,
#     259                                  retry_counter + 1, base_url, accepts_clientid,
# --> 260                                  extract_body, requests_kwargs, post_json)
#     261
#     262     def _get(self, *args, **kwargs):  # Backwards compatibility.
#
# /opt/conda/lib/python3.6/site-packages/googlemaps/client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     258             return self._request(url, params, first_request_time,
#     259                                  retry_counter + 1, base_url, accepts_clientid,
# --> 260                                  extract_body, requests_kwargs, post_json)
#     261
#     262     def _get(self, *args, **kwargs):  # Backwards compatibility.
#
# /opt/conda/lib/python3.6/site-packages/googlemaps/client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     258             return self._request(url, params, first_request_time,
#     259                                  retry_counter + 1, base_url, accepts_clientid,
# --> 260                                  extract_body, requests_kwargs, post_json)
#     261
#     262     def _get(self, *args, **kwargs):  # Backwards compatibility.
#
# /opt/conda/lib/python3.6/site-packages/googlemaps/client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     258             return self._request(url, params, first_request_time,
#     259                                  retry_counter + 1, base_url, accepts_clientid,
# --> 260                                  extract_body, requests_kwargs, post_json)
#     261
#     262     def _get(self, *args, **kwargs):  # Backwards compatibility.
#
# /opt/conda/lib/python3.6/site-packages/googlemaps/client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     258             return self._request(url, params, first_request_time,
#     259                                  retry_counter + 1, base_url, accepts_clientid,
# --> 260                                  extract_body, requests_kwargs, post_json)
#     261
#     262     def _get(self, *args, **kwargs):  # Backwards compatibility.
#
# /opt/conda/lib/python3.6/site-packages/googlemaps/client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     258             return self._request(url, params, first_request_time,
#     259                                  retry_counter + 1, base_url, accepts_clientid,
# --> 260                                  extract_body, requests_kwargs, post_json)
#     261
#     262     def _get(self, *args, **kwargs):  # Backwards compatibility.
#
# /opt/conda/lib/python3.6/site-packages/googlemaps/client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     258             return self._request(url, params, first_request_time,
#     259                                  retry_counter + 1, base_url, accepts_clientid,
# --> 260                                  extract_body, requests_kwargs, post_json)
#     261
#     262     def _get(self, *args, **kwargs):  # Backwards compatibility.
#
# /opt/conda/lib/python3.6/site-packages/googlemaps/client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     258             return self._request(url, params, first_request_time,
#     259                                  retry_counter + 1, base_url, accepts_clientid,
# --> 260                                  extract_body, requests_kwargs, post_json)
#     261
#     262     def _get(self, *args, **kwargs):  # Backwards compatibility.
#
# /opt/conda/lib/python3.6/site-packages/googlemaps/client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     258             return self._request(url, params, first_request_time,
#     259                                  retry_counter + 1, base_url, accepts_clientid,
# --> 260                                  extract_body, requests_kwargs, post_json)
#     261
#     262     def _get(self, *args, **kwargs):  # Backwards compatibility.
#
# /opt/conda/lib/python3.6/site-packages/googlemaps/client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     258             return self._request(url, params, first_request_time,
#     259                                  retry_counter + 1, base_url, accepts_clientid,
# --> 260                                  extract_body, requests_kwargs, post_json)
#     261
#     262     def _get(self, *args, **kwargs):  # Backwards compatibility.
#
# /opt/conda/lib/python3.6/site-packages/googlemaps/client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     258             return self._request(url, params, first_request_time,
#     259                                  retry_counter + 1, base_url, accepts_clientid,
# --> 260                                  extract_body, requests_kwargs, post_json)
#     261
#     262     def _get(self, *args, **kwargs):  # Backwards compatibility.
#
# /opt/conda/lib/python3.6/site-packages/googlemaps/client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     258             return self._request(url, params, first_request_time,
#     259                                  retry_counter + 1, base_url, accepts_clientid,
# --> 260                                  extract_body, requests_kwargs, post_json)
#     261
#     262     def _get(self, *args, **kwargs):  # Backwards compatibility.
#
# /opt/conda/lib/python3.6/site-packages/googlemaps/client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     201         elapsed = datetime.now() - first_request_time
#     202         if elapsed > self.retry_timeout:
# --> 203             raise googlemaps.exceptions.Timeout()
#     204
#     205         if retry_counter > 0:
#
# Timeout:

# %%
#confirm data
print(data)
# Out:
# [[40.68108, -73.940821], [40.7493954, -73.9773495], [40.6818029, -73.9582756], [0, 0], [40.7128683, -73.9874276], [40.682543, -73.945256], [40.682543, -73.945256], [40.6805081, -73.9435824], [40.7490605, -73.9775252], [40.6921177, -73.9467052], [40.7318791, -73.9570428], [40.73380299999999, -73.9564633], [40.726905, -73.9547872], [40.72502799999999, -73.950801], [40.7308086, -73.9537311], [40.7311995, -73.95295039999999], [40.7312815, -73.9521698], [0, 0], [40.6952276, -73.9631445], [40.6931936, -73.961744], [40.6931936, -73.961744], [40.6931936, -73.961744], [40.6924983, -73.961744], [40.6924983, -73.961744], [40.7554466, -73.975793], [40.7554466, -73.975793], [40.6938548, -73.9644017], [40.689316, -73.9928051], [40.6937354, -73.9923175], [40.6943848, -73.993402], [40.6939556, -73.99181999999999], [40.6937354, -73.9923175], [40.6925125, -73.99232310000001], [40.72486800000001, -73.952754], [40.7312434, -73.9524453], [0, 0], [40.7325839, -73.95345549999999], [40.7320518, -73.9513432], [40.7320898, -73.9510677], [40.7317745, -73.95102179999999], [40.7321148, -73.9507003], [40.7321148, -73.9507003], [40.70278589999999, -73.94332159999999], [40.7027433, -74.0122906], [40.7017731, -73.9443557], [40.70124759999999, -73.9455801], [40.7013978, -73.9424471], [40.7127753, -74.0059728], [40.706643, -73.9445468], [40.7976799, -73.96190469999999], [40.707444, -73.9435939], [40.7072994, -73.94101619999999], [40.7045215, -73.94133269999999], [40.7031832, -73.93391059999999], [40.6935587, -73.9932298], [40.69410999999999, -73.9926904], [40.6939468, -73.9933102], [40.6935605, -73.9933102], [40.6883734, -73.9930524], [40.7141707, -73.9871717], [40.6887457, -73.98421309999999], [40.68962550000001, -73.9869514], [40.6787186, -73.9768046], [40.6774566, -73.96954989999999], [40.7145983, -74.0112577], [40.677867, -73.971915], [40.6797415, -73.9733265], [40.6793374, -73.9715013], [40.67906, -73.977329], [40.7052103, -73.961505], [40.7093375, -73.9614193], [40.7093153, -73.9613222], [40.7328264, -73.9586904], [40.7347543, -73.9575883], [40.723685, -73.9519727], [40.726905, -73.9547872], [40.7332158, -73.95409839999999], [40.7369686, -73.9534785], [40.6950036, -73.9474399], [40.69497680000001, -73.94772689999999], [40.694621, -73.951171], [40.693954, -73.950413], [40.693939, -73.950547], [40.6845914, -73.9407812], [40.6846774, -73.9395527], [40.68392780000001, -73.9460967], [40.683314, -73.941278], [40.6930763, -73.9946294], [43.2994285, -74.21793260000001], [40.6888776, -73.9924379], [40.6895113, -73.9928376], [40.6871228, -73.9904178], [40.687503, -73.97500099999999], [40.687503, -73.97500099999999], [40.6888555, -73.9751287], [0, 0], [0, 0], [40.6897679, -73.9790513], [40.688416, -73.981977], [40.6850882, -73.9793861], [40.6846239, -73.97941019999999], [40.6846239, -73.97941019999999], [0, 0], [40.6882051, -73.9906932], [40.6903093, -73.99381520000001], [40.6906331, -73.9950089], [40.6932527, -73.9942525], [40.6916525, -73.9921165], [40.709587, -74.0168662], [40.7593565, -73.830349], [40.8522426, -73.90721769999999], [40.6882682, -73.9868481], [40.68628, -73.98692849999999], [40.6896668, -73.9915483], [40.6886668, -73.9917937], [40.685015, -73.979238], [40.6845861, -73.9791888], [40.6848529, -73.980666], [40.98322659999999, -73.6859518], [40.7182862, -74.0103894], [40.7179534, -74.0104604], [40.7037052, -74.0116649], [40.6868261, -73.9851264], [40.68962550000001, -73.9869514], [40.7183514, -73.9857166], [40.6922277, -73.99140489999999], [40.6925125, -73.99232310000001], [40.6925125, -73.99232310000001], [40.6925125, -73.99232310000001], [40.69181349999999, -73.9917047], [40.6932626, -73.9694351], [40.7554466, -73.975793], [40.67897869999999, -73.973429], [40.6702665, -73.95080039999999], [40.673966, -73.9546529], [40.6722396, -73.952893], [40.6781145, -73.9390475], [40.711633, -73.96277599999999], [40.7830603, -73.9712488], [40.693802, -73.99449299999999], [40.6914268, -73.9918869], [0, 0], [40.68893190000001, -73.9809171], [40.716735, -73.96160499 ...

# %%
#write data.csv
import csv

extractdate = dateformat.replace('/', '-')
with open(datadir + 'geodata_' + extractdate + '_' + str(len(data)) + '_' + file, 'w') as f:
    writer = csv.writer(f)
    writer.writerows(data)
print('Finished!')
# Out:
# Finished!

# %%
#print(geocode(['MACDOUNGH ST', '142']))
# Out:
# [40.68108, -73.940821]

# %%
#data = [[geocode(x)[0], geocode(x)[1]] for x in data]
#print(data)

# %%
#data = data[~np.isnan(data).any(axis=1)]

# %%
#read data.csv
import csv

with open('data.csv', 'r') as f:
    reader = csv.reader(f, quoting=csv.QUOTE_NONNUMERIC)
    data = list(reader)
#print(data)
print('Finished!')
# Out:
# [[40.68108, -73.940821], [40.7493954, -73.9773495], [40.6818029, -73.9582756], [40.7129833, -73.9895488], [40.6850293, -73.94949489999999], [40.682543, -73.945256], [40.682543, -73.945256], [40.6805081, -73.9435824], [40.749027, -73.9775219], [40.6921177, -73.9467052], [40.7318791, -73.9570428], [40.73380299999999, -73.9564633], [40.726905, -73.9547872], [40.72502799999999, -73.950801], [40.7308086, -73.9537311], [40.7311995, -73.95295039999999], [40.7312815, -73.9521698], [0.0, 0.0], [40.6952276, -73.9631445], [40.6931936, -73.961744], [40.6931936, -73.961744], [40.6931936, -73.961744], [40.6924983, -73.961744], [40.6924983, -73.961744], [40.693379, -73.9697106], [40.6925839, -73.9694729], [40.6938548, -73.9644017], [40.689316, -73.9928051], [40.6937354, -73.9923175], [40.6943848, -73.993402], [40.69500559999999, -73.9950751], [40.8205487, -73.9366757], [40.6937354, -73.9923175], [40.6925125, -73.99232310000001], [40.72486800000001, -73.952754], [40.7312434, -73.9524453], [0.0, 0.0], [40.7325839, -73.95345549999999], [40.7320518, -73.9513432], [40.7320898, -73.9510677], [40.7317745, -73.95102179999999], [40.7321148, -73.9507003], [40.7321148, -73.9507003], [40.70278589999999, -73.94332159999999], [40.7037235, -73.9430713], [40.70176499999999, -73.9443465], [40.70124759999999, -73.9455801], [40.7014164, -73.9422336], [40.7062823, -73.94445499999999], [40.706643, -73.9445468], [40.7976799, -73.96190469999999], [40.707444, -73.9435939], [40.7072994, -73.94101619999999], [40.7045215, -73.94133269999999], [40.7033406, -73.934056], [40.6935587, -73.9932298], [40.69410999999999, -73.9926904], [40.6939468, -73.9933102], [40.6935605, -73.9933102], [40.6883734, -73.9930524], [40.7141707, -73.9871717], [40.6887457, -73.98421309999999], [40.68962550000001, -73.9869514], [40.6787186, -73.9768046], [40.6774566, -73.96954989999999], [40.6773527, -73.9708855], [40.677867, -73.971915], [40.6797415, -73.9733265], [40.6793374, -73.9715013], [40.67906, -73.977329], [40.7052103, -73.961505], [40.7093375, -73.9614193], [40.7093153, -73.9613222], [40.7328264, -73.9586904], [40.7347543, -73.9575883], [40.723685, -73.9519727], [40.726905, -73.9547872], [40.7332158, -73.95409839999999], [40.7369686, -73.9534785], [40.6950036, -73.9474399], [40.69497680000001, -73.94772689999999], [40.694621, -73.951171], [40.693947, -73.950481], [40.693939, -73.950547], [40.6845914, -73.9407812], [40.6846774, -73.9395527], [40.68392780000001, -73.9460967], [40.683314, -73.941278], [40.6930763, -73.9946294], [40.6903237, -73.9916688], [40.6888776, -73.9924379], [40.6894102, -73.99249510000001], [40.6871228, -73.9904178], [40.687503, -73.97500099999999], [40.687503, -73.97500099999999], [40.6888555, -73.9751287], [0.0, 0.0], [0.0, 0.0], [40.6897679, -73.9790513], [40.688416, -73.981977]]
